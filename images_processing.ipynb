# %% [markdown]
# <a href="https://colab.research.google.com/github/jlamarleon/Images_Processing/blob/main/images_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![blog-image-processing.jpg](data:image/jpeg;base64,...
#
# ---
#
# ...)
# Images Processing, OpenCv plus Python

# %%
import numpy
print('-Hello-')
# Out:
# -Hello-
